# %% [markdown]
# # Домашнее задание 1

# %% [markdown]
# ## Задание 1:
#
#
# Переведите содержимое файла purchase_log.txt в словарь purchases вида:
#  {'1840e0b9d4': 'Продукты', ...}
#
# Пример работы программы при выводе первых двух элементов словаря purchases:
#
# 1840e0b9d4 ‘Продукты‘
#
# 4e4f90fcfb  ‘Электроника‘

# %%
import json

# %%
purchases = {}

with open('purchase_log.txt', encoding='utf-8') as f:
    f.readline()

    for line in f:
        line = line.strip()

        dict_line = json.loads(line)
        
        key = dict_line['user_id']
        value = dict_line['category']
        
        purchases[key] = value

for key, value in list(purchases.items())[:2]:
    print(key, value)
# Out:
# 1840e0b9d4 Продукты
# 4e4f90fcfb Электроника

# %% [markdown]
# ## Задание 2:
#
# Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки. Если покупка была, сам файл visit_log.csv изменять не надо.
#
# Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
#
# Учтите условия для данных:
#
# содержимое purchase_log.txt помещается в оперативную память компьютера;
#
# содержимое visit_log.csv — нет, используйте только построчную обработку этого файла.
#
#
#
# Примеры работы программы при выводе первых трёх строк файла funnel.csv:
#
# user_id,source,category
#
# 1840e0b9d4,other,Продукты
#
# 4e4f90fcfb,context,Электроника

# %%
with open('visit_log.csv', 'r', encoding='utf-8') as f:
    with open('funnel.csv', 'w', encoding='utf-8') as f2write:

        header = f.readline().strip()
        f2write.write(f"{header},category\n")
        
        for line in f:
            line = line.strip()
            
            csv_data = line.split(',')
            user_id = csv_data[0]
            source = csv_data[1]
            
            if user_id in purchases:
                category = purchases[user_id]
                
                f2write.write(f"{user_id},{source},{category}\n")

# %%
with open('funnel.csv', 'r', encoding='utf-8') as f_result:
    print(f_result.readline().strip())
    print(f_result.readline().strip())
    print(f_result.readline().strip())
# Out:
# user_id,source,category
# 1840e0b9d4,other,Продукты
# 4e4f90fcfb,context,Электроника
